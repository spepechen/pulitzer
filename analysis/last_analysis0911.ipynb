# %%
# %matplotlib inline

import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("single_clustered0911.csv")  #individual awards

# %%
df[:5]
# Out:
#                name gender gender_add  year                 category  \
# 0     Caryle Murphy   andy     female  1991  International-Reporting
# 1        E.R. Shipp   andy     female  1996               Commentary
# 2     Jackie Crosby   andy     female  1985    Specialized-Reporting
# 3         Jo Becker   andy     female  2008       National-Reporting
# 4  Marjie Lundstrom   andy     female  1991       National-Reporting
#
#                      publication publication2 organizational first_name  \
# 0            The Washington Post          NaN             no     Caryle
# 1            New York Daily News          NaN             no       E.R.
# 2  Macon (GA) Telegraph and News          NaN             no     Jackie
# 3            The Washington Post          NaN             no         Jo
# 4           Gannett News Service          NaN             no     Marjie
#
#   mutiple org note
# 0         NaN  NaN
# 1         NaN  NaN
# 2         NaN  NaN
# 3         NaN  NaN
# ...

# %%
df2 = df.copy()

# %%
#new_df.drop('year','category',1) 

df2.drop(df2.columns[[3,4,5,6,7,8,9,10]], axis=1, inplace=True)
df2.drop('gender',1)
# Out:
#                             name gender_add
# 0                  Caryle Murphy     female
# 1                     E.R. Shipp     female
# 2                  Jackie Crosby     female
# 3                      Jo Becker     female
# 4               Marjie Lundstrom     female
# 5                 Paige St. John     female
# 6                  Ren_e C. Byer     female
# 7            Ada Louise Huxtable     female
# 8    Alejandra Xanic von Bertrab     female
# 9               Alexandra Berzon     female
# 10               Alice Steinbach     female
# 11               Alison Sherwood     female
# 12              Alix M. Freedman     female
# 13            Amy Dockser Marcus     female
# 14                Amy Ellis Nutt     female
# 15                    Amy Harmon     female
# 16                Andrea Elliott     female
# 17                  Ann Desantis     female
# 18            Ann Marie Lipinski     female
# 19                   Ann Telnaes     female
# ...

# %%
df2['gender_add'].value_counts()
# Out:
# male      700
# female    141
# dtype: int64

# %%
df2['gender_add'].value_counts().plot(kind = 'bar', color = 'yellow', title = 'Gender of Personal Pulitzer Winners')

# %%
Is the percentage increase each year? 
1. add a col of percentage of fe

col: total in a year/ 
col: female total in a year

# %%
df3 = pd.read_csv("pulitzer_winner_refined - output.csv")  #individual awards 
indie_df = df3[df3['organizational'] == 'no']
indie_df
# Out:
#                                    category  \
# 224                             Photography
# 225                      National-Reporting
# 226                 International-Reporting
# 227                 International-Reporting
# 228                    Editorial-Cartooning
# 229                 International-Reporting
# 230                 International-Reporting
# 231                 International-Reporting
# 232                 International-Reporting
# 233                 International-Reporting
# 234                 International-Reporting
# 235                               Reporting
# 236                               Reporting
# 237                               Reporting
# 238                               Reporting
# 239                               Reporting
# 240                 Investigative-Reporting
# 241                      National-Reporting
# 242                       Editorial-Writing
# 243                       Editorial-Writing
# ...

# %%
indie_df['gender'].value_counts()
# Out:
# male             676
# female           116
# andy              64
# mostly_male       29
# mostly_female     22
# dtype: int64

# %%
add new gender col in this 
1. if name1 = name2 
2. assign gender2 to df1's col

# %%
name/ year/ gender_clusted

# %%
pd.merge(restaurant_ids_dataframe, restaurant_review_frame, on='business_id', how='outer')
