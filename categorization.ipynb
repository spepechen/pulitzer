# %%
# %matplotlib inline

import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("almightysoma.csv")  #all awards

# %%
df[:10]
# Out:
#          category              publication                name  year
# 0  Beat-Reporting      The Washington Post         Dana Priest  2006
# 1  Beat-Reporting  The Wall Street Journal  Amy Dockser Marcus  2005
# 2  Beat-Reporting  The Wall Street Journal       Daniel Golden  2004
# 3  Beat-Reporting        The Baltimore Sun       Diana K. Sugg  2003
# 4  Beat-Reporting       The New York Times  Gretchen Morgenson  2002
# 5  Beat-Reporting       The New York Times  David Cay Johnston  2001
# 6  Beat-Reporting   St. Paul Pioneer Press     George Dohrmann  2000
# 7  Beat-Reporting        Los Angeles Times  Michael A. Hiltzik  1999
# 8  Beat-Reporting        Los Angeles Times       Chuck Philips  1999
# 9  Beat-Reporting       The New York Times    Linda Greenhouse  1998

# %%
for i in lendf
df[''] = df
    
df2['name'] = df2['name'].apply( lambda s: HumanName( s ) if not ( isinstance( s,float ) and isnan( s ) )  else s )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-7e159020e85a> in <module>()
# ----> 1 if df['publication'] == df['name']:
#       2     print df
#
# /Users/Spepe/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __nonzero__(self)
#     712         raise ValueError("The truth value of a {0} is ambiguous. "
#     713                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 714                          .format(self.__class__.__name__))
#     715
#     716     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# #Adding New Column 'organizational'
#
# if it is a group award, then the value is 'yes'.
#
# if it is an individual award, then the value is 'no'.
#
# if it is 'No Award', then 'none'.

# %%
df['organizational'] = 'not defined'

# %%
for i in range(len(df['name'])): 
    if df['name'][i] == df['publication'][i] and df['name'][i] != "No Award" :
        df['organizational'][i] = 'yes'
#         print i, df.ix[i]
#         print "================================================================================"
#         df['organizational'] = 'yes'
# Out:
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
df[df['organizational'] == 'yes']
# Out:
#                      category                                     publication  \
# 370         Editorial-Writing                               The Boston Herald
# 607   International-Reporting                                            None
# 918            Public-Service                            The Post and Courier
# 919            Public-Service                                 The Guardian US
# 920            Public-Service                             The Washington Post
# 921            Public-Service                                    Sun Sentinel
# 922            Public-Service                       The Philadelphia Inquirer
# 923            Public-Service                               Los Angeles Times
# 924            Public-Service                     Bristol (VA) Herald Courier
# 926            Public-Service                             The Washington Post
# 927            Public-Service                         The Wall Street Journal
# ...

# %%
df[df['name'] == 'No Award']
# Out:
#                               category publication      name  year  \
# 149                          Criticism    No Award  No Award  1992
# 214               Editorial-Cartooning    No Award  No Award  1973
# 222               Editorial-Cartooning    No Award  No Award  1965
# 227               Editorial-Cartooning    No Award  No Award  1960
# 251               Editorial-Cartooning    No Award  No Award  1936
# 264               Editorial-Cartooning    No Award  No Award  1923
# 295                  Editorial-Writing    No Award  No Award  1993
# 309                  Editorial-Writing    No Award  No Award  1981
# 359                  Editorial-Writing    No Award  No Award  1935
# 362                  Editorial-Writing    No Award  No Award  1932
# 364                  Editorial-Writing    No Award  No Award  1930
# 374                  Editorial-Writing    No Award  No Award  1921
# 376                  Editorial-Writing    No Award  No Award  1919
# ...

# %%
for i in range(len(df['name'])): 
    if df['name'][i] == 'No Award': 
        df['organizational'][i] = 'none'
# Out:
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
df[df['name'] == 'No Award']
# Out:
#                               category publication      name  year  \
# 149                          Criticism    No Award  No Award  1992
# 214               Editorial-Cartooning    No Award  No Award  1973
# 222               Editorial-Cartooning    No Award  No Award  1965
# 227               Editorial-Cartooning    No Award  No Award  1960
# 251               Editorial-Cartooning    No Award  No Award  1936
# 264               Editorial-Cartooning    No Award  No Award  1923
# 295                  Editorial-Writing    No Award  No Award  1993
# 309                  Editorial-Writing    No Award  No Award  1981
# 359                  Editorial-Writing    No Award  No Award  1935
# 362                  Editorial-Writing    No Award  No Award  1932
# 364                  Editorial-Writing    No Award  No Award  1930
# 374                  Editorial-Writing    No Award  No Award  1921
# 376                  Editorial-Writing    No Award  No Award  1919
# ...

# %%
df[df['name'] == "staff"]
# Out:
#                   category          publication   name  year organizational
# 410  Explanatory-Reporting  The New York Times   staff  2010    not defined

# %%
df.ix[410]
# Out:
# category          Explanatory-Reporting
# publication         The New York Times
# name                              staff
# year                               2010
# organizational              not defined
# Name: 410, dtype: object

# %%
df[df['name'] == "Staff"]
# Out:
#                                        category  \
# 19                    Breaking-News-Photography
# 34                    Breaking-News-Photography
# 35                    Breaking-News-Photography
# 39                    Breaking-News-Photography
# 42                      Breaking-News-Reporting
# 43                      Breaking-News-Reporting
# 44                      Breaking-News-Reporting
# 45                      Breaking-News-Reporting
# 47                      Breaking-News-Reporting
# 48                      Breaking-News-Reporting
# 49                      Breaking-News-Reporting
# 50                      Breaking-News-Reporting
# 51                      Breaking-News-Reporting
# 52                      Breaking-News-Reporting
# 53                      Breaking-News-Reporting
# 54                      Breaking-News-Reporting
# 55                      Breaking-News-Reporting
# 56                      Breaking-News-Reporting
# ...

# %%
for i in range(len(df['name'])): 
    if df['name'][i] == 'Staff': 
        df['organizational'][i] = 'yes'
# Out:
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
df[df['name'] == "Staff"]
# Out:
#                                        category  \
# 19                    Breaking-News-Photography
# 34                    Breaking-News-Photography
# 35                    Breaking-News-Photography
# 39                    Breaking-News-Photography
# 42                      Breaking-News-Reporting
# 43                      Breaking-News-Reporting
# 44                      Breaking-News-Reporting
# 45                      Breaking-News-Reporting
# 47                      Breaking-News-Reporting
# 48                      Breaking-News-Reporting
# 49                      Breaking-News-Reporting
# 50                      Breaking-News-Reporting
# 51                      Breaking-News-Reporting
# 52                      Breaking-News-Reporting
# 53                      Breaking-News-Reporting
# 54                      Breaking-News-Reporting
# 55                      Breaking-News-Reporting
# 56                      Breaking-News-Reporting
# ...

# %%
df[df["organizational"] == 'not defined']
# Out:
#                                    category  \
# 0                            Beat-Reporting
# 1                            Beat-Reporting
# 2                            Beat-Reporting
# 3                            Beat-Reporting
# 4                            Beat-Reporting
# 5                            Beat-Reporting
# 6                            Beat-Reporting
# 7                            Beat-Reporting
# 8                            Beat-Reporting
# 9                            Beat-Reporting
# 10                           Beat-Reporting
# 11                           Beat-Reporting
# 12                           Beat-Reporting
# 13                           Beat-Reporting
# 14                           Beat-Reporting
# 15                           Beat-Reporting
# 16                           Beat-Reporting
# 17                           Beat-Reporting
# 18                           Beat-Reporting
# 20                Breaking-News-Photography
# ...

# %%
len(df[df["organizational"] == 'not defined'])
# Out:
# 928

# %%
for i in range(len(df)): 
    if df["organizational"][i] == 'not defined': 
        df["organizational"][i] = 'no'
# Out:
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
df[df["organizational"] == 'no']
# Out:
#                                    category  \
# 0                            Beat-Reporting
# 1                            Beat-Reporting
# 2                            Beat-Reporting
# 3                            Beat-Reporting
# 4                            Beat-Reporting
# 5                            Beat-Reporting
# 6                            Beat-Reporting
# 7                            Beat-Reporting
# 8                            Beat-Reporting
# 9                            Beat-Reporting
# 10                           Beat-Reporting
# 11                           Beat-Reporting
# 12                           Beat-Reporting
# 13                           Beat-Reporting
# 14                           Beat-Reporting
# 15                           Beat-Reporting
# 16                           Beat-Reporting
# 17                           Beat-Reporting
# 18                           Beat-Reporting
# 20                Breaking-News-Photography
# ...

# %% [markdown]
# ##Some hard to categorize
#
# leave it as 'not defined'

# %%
df.ix[112] #awarded to all American journalists in war period 

#http://www.pulitzer.org/bycat/Correspondence
# Out:
# category          Correspondence
# publication                 None
# name                 Group Award
# year                        1941
# organizational                no
# Name: 112, dtype: object

# %%
df["organizational"][112] = 'not define'
# Out:
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df.ix[112]
# Out:
# category          Correspondence
# publication                 None
# name                 Group Award
# year                        1941
# organizational        not define
# Name: 112, dtype: object

# %%
df
# Out:
#                                    category  \
# 0                            Beat-Reporting
# 1                            Beat-Reporting
# 2                            Beat-Reporting
# 3                            Beat-Reporting
# 4                            Beat-Reporting
# 5                            Beat-Reporting
# 6                            Beat-Reporting
# 7                            Beat-Reporting
# 8                            Beat-Reporting
# 9                            Beat-Reporting
# 10                           Beat-Reporting
# 11                           Beat-Reporting
# 12                           Beat-Reporting
# 13                           Beat-Reporting
# 14                           Beat-Reporting
# 15                           Beat-Reporting
# 16                           Beat-Reporting
# 17                           Beat-Reporting
# 18                           Beat-Reporting
# 19                Breaking-News-Photography
# ...

# %% [markdown]
# # Add new column 'gender'
#
# use first name to estimate gender (Sex mechaine).

# %%
from nameparser import HumanName
import sexmachine.detector as gender
d = gender.Detector()

# %%
df['first_name'] = 'none'

# %%
#df['first_name'] = df['name'].apply(lambda s: str(s).split()[0])

# %% [markdown]
# https://pypi.python.org/pypi/SexMachine/

# %%
indie_df = df[df['organizational'] == 'no'] 
indie_df
# Out:
#                                    category  \
# 0                            Beat-Reporting
# 1                            Beat-Reporting
# 2                            Beat-Reporting
# 3                            Beat-Reporting
# 4                            Beat-Reporting
# 5                            Beat-Reporting
# 6                            Beat-Reporting
# 7                            Beat-Reporting
# 8                            Beat-Reporting
# 9                            Beat-Reporting
# 10                           Beat-Reporting
# 11                           Beat-Reporting
# 12                           Beat-Reporting
# 13                           Beat-Reporting
# 14                           Beat-Reporting
# 15                           Beat-Reporting
# 16                           Beat-Reporting
# 17                           Beat-Reporting
# 18                           Beat-Reporting
# 20                Breaking-News-Photography
# ...

# %%
indie_df['first_name'] = indie_df['name'].apply(lambda s: str(s).split()[0])
indie_df
#df['first_name'] = df['name'].apply(lambda s: str(s).split()[0])
# Out:
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                
csv', sep=',', encoding='utf-8')

# %% [markdown]
# ##fix some error
#
# sex machine evaluate NaN as 'andy', those are organizational awards
#
# to get the number of true "andy", and then see whether there's a need to manually evaluate the gender

# %% [markdown]
# # <font color = red> UNSOLVED

# %%
df[df['organizational'] == 'yes']
# Out:
#                        category                           publication  \
# 19    Breaking-News-Photography               St. Louis Post-Dispatch
# 34    Breaking-News-Photography               The Dallas Morning News
# 35    Breaking-News-Photography                      Associated Press
# 39    Breaking-News-Photography                    The New York Times
# 42      Breaking-News-Reporting                    The Seattle Times
# 43      Breaking-News-Reporting                      The Boston Globe
# 44      Breaking-News-Reporting                       The Denver Post
# 45      Breaking-News-Reporting            The Tuscaloosa (Ala.) News
# 47      Breaking-News-Reporting                     The Seattle Times
# 48      Breaking-News-Reporting                    The New York Times
# 49      Breaking-News-Reporting                   The Washington Post
# 50      Breaking-News-Reporting                         The Oregonian
# ...

# %%
df[(df['gender'] == 'andy') & (df['organizational'] == 'yes')]#['gender'] #= 'not applied'
# Out:
#                        category                           publication  \
# 19    Breaking-News-Photography               St. Louis Post-Dispatch
# 34    Breaking-News-Photography               The Dallas Morning News
# 35    Breaking-News-Photography                      Associated Press
# 39    Breaking-News-Photography                    The New York Times
# 42      Breaking-News-Reporting                    The Seattle Times
# 43      Breaking-News-Reporting                      The Boston Globe
# 44      Breaking-News-Reporting                       The Denver Post
# 45      Breaking-News-Reporting            The Tuscaloosa (Ala.) News
# 47      Breaking-News-Reporting                     The Seattle Times
# 48      Breaking-News-Reporting                    The New York Times
# 49      Breaking-News-Reporting                   The Washington Post
# 50      Breaking-News-Reporting                         The Oregonian
# ...

# %%
#df_gender['gender'] = df_gender['first_name'].apply( lambda s: d.get_gender(s))

# %%
print str(df['gender'][0])
# Out:
# female

# %%
#df_gender['gender'] = df_gender['first_name'].apply( lambda s: d.get_gender(s))
# Out:
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %% [markdown]
# ##Fix some wrong categories

# %%
df[df['first_name'] == 'Photo']
# Out:
#                        category          publication         name  year  \
# 41    Breaking-News-Photography  Rocky Mountain News  Photo Staff  2000
# 446         Feature-Photography     Associated Press  Photo Staff  1999
# 1072      Spot-News-Photography     Associated Press  Photo Staff  1999
# 1082      Spot-News-Photography          The Tribune  Photo Staff  1990
#
#      organizational first_name gender
# 41               no      Photo   andy
# 446              no      Photo   andy
# 1072             no      Photo   andy
# 1082             no      Photo   andy

# %%
df['organizational'][41] = 'yes'
df['organizational'][446]= 'yes'
df['organizational'][1072]= 'yes'
df['organizational'][1082]= 'yes'
# Out:
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from IPython.kernel.zmq import kernelapp as app
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
print df['organizational'][41]
print df['organizational'][446]
print df['organizational'][1072]
print df['organizational'][1082]
# Out:
# yes
# yes
# yes
# yes

# %%
df['first_name'][41] = 'No'
df['first_name'][446]= 'No'
df['first_name'][1072]= 'No'
df['first_name'][1082]= 'No'
# Out:
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from IPython.kernel.zmq import kernelapp as app
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
df[df['first_name'] == 'Photography']
# Out:
#                        category          publication               name  year  \
# 38    Breaking-News-Photography  Rocky Mountain News  Photography Staff  2003
# 1088      Spot-News-Photography         The Register  Photography Staff  1985
#
#      organizational   first_name gender
# 38               no  Photography   andy
# 1088             no  Photography   andy

# %%
df['organizational'][38] = 'yes'
df['organizational'][1088]= 'yes'
# Out:
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from IPython.kernel.zmq import kernelapp as app

# %%
df[df['first_name'] == 'Editorial']
# Out:
#                                  category  \
# 267                     Editorial-Writing
# 289                     Editorial-Writing
# 678  Local-General-or-Spot-News-Reporting
# 778         Local-Reporting;-Edition-Time
#
#                                       publication             name  year  \
# 267                                 The Oregonian  Editorial Staff  2014
# 289                                    Daily News  Editorial Board  1999
# 678                 Fort Wayne (IN) News-Sentinel  Editorial Staff  1983
# 778  Providence (RI) Journal and Evening Bulletin  Editorial Staff  1953
#
#     organizational first_name gender
# 267             no  Editorial   andy
# 289             no  Editorial   andy
# 678             no  Editorial   andy
# 778             no  Editorial   andy

# %%
df['organizational'][267] = 'yes'
df['organizational'][289]= 'yes'
df['organizational'][678]= 'yes'
df['organizational'][778]= 'yes'
# Out:
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from IPython.kernel.zmq import kernelapp as app
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
df[df['first_name'] == 'Staff']
# Out:
#                 category             publication                 name  year  \
# 467  Feature-Photography  Boston Herald American  Staff Photographers  1979
#
#     organizational first_name gender
# 467             no      Staff   andy

# %%
df['organizational'][467] = 'yes'
# Out:
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df[df['organizational'] == 'yes']
# Out:
#                        category                           publication  \
# 19    Breaking-News-Photography               St. Louis Post-Dispatch
# 34    Breaking-News-Photography               The Dallas Morning News
# 35    Breaking-News-Photography                      Associated Press
# 38    Breaking-News-Photography                   Rocky Mountain News
# 39    Breaking-News-Photography                    The New York Times
# 41    Breaking-News-Photography                   Rocky Mountain News
# 42      Breaking-News-Reporting                    The Seattle Times
# 43      Breaking-News-Reporting                      The Boston Globe
# 44      Breaking-News-Reporting                       The Denver Post
# 45      Breaking-News-Reporting            The Tuscaloosa (Ala.) News
# 47      Breaking-News-Reporting                     The Seattle Times
# 48      Breaking-News-Reporting                    The New York Times
# ...

# %%
df[(df['first_name'].notnull()) & (df['organizational'] == 'yes')]

# http://pandas.pydata.org/pandas-docs/stable/missing_data.html
# Out:
#                                   category  \
# 38               Breaking-News-Photography
# 41               Breaking-News-Photography
# 267                      Editorial-Writing
# 289                      Editorial-Writing
# 446                    Feature-Photography
# 467                    Feature-Photography
# 678   Local-General-or-Spot-News-Reporting
# 778          Local-Reporting;-Edition-Time
# 1072                 Spot-News-Photography
# 1082                 Spot-News-Photography
# 1088                 Spot-News-Photography
#
#                                        publication                 name  year  \
# 38                             Rocky Mountain News    Photography Staff  2003
# 41                             Rocky Mountain News          Photo Staff  2000
# 267                                  The Oregonian      Editorial Staff  2014
# 289                                     Daily News      Editorial Board  1999
# ...

# %% [markdown]
# #Summary (temp)

# %%
df['publication'].value_counts()
# Out:
# The New York Times                            109
# The Washington Post                            66
# Associated Press                               51
# Los Angeles Times                              49
# The Wall Street Journal                        39
# The Boston Globe                               37
# Chicago Tribune                                29
# No Award                                       28
# The Philadelphia Inquirer                      25
# Newsday                                        21
# The Miami Herald                               18
# St. Louis Post-Dispatch                        16
# The Seattle Times                              15
# The Dallas Morning News                        15
# The Baltimore Sun                              13
# Detroit Free Press                             13
# New York Daily News                            12
# Chicago Daily News                             12
# Chicago Sun-Times                              11
# ...

# %%
df['gender'].value_counts()
# Out:
# male             669
# andy             294
# female           113
# mostly_male       29
# mostly_female     22
# dtype: int64

# %%
#female winners #135 rows 

df[(df['organizational'] == 'no') & (df['gender'] == 'female') | (df['gender'] == 'mostly_female')] #.value_counts()
# Out:
#                                        category  \
# 0                                Beat-Reporting
# 1                                Beat-Reporting
# 3                                Beat-Reporting
# 4                                Beat-Reporting
# 9                                Beat-Reporting
# 17                               Beat-Reporting
# 18                               Beat-Reporting
# 28                    Breaking-News-Photography
# 29                    Breaking-News-Photography
# 30                    Breaking-News-Photography
# 36                    Breaking-News-Photography
# 60                                   Commentary
# 63                                   Commentary
# 65                                   Commentary
# 68                                   Commentary
# 70                                   Commentary
# 74                                   Commentary
# 76                                   Commentary
# ...

# %%
#male winners #698 rows 

df[(df['organizational'] == 'no') & (df['gender'] == 'male') | (df['gender'] == 'mostly_male')]
# Out:
#                                    category  \
# 2                            Beat-Reporting
# 5                            Beat-Reporting
# 6                            Beat-Reporting
# 7                            Beat-Reporting
# 8                            Beat-Reporting
# 10                           Beat-Reporting
# 11                           Beat-Reporting
# 12                           Beat-Reporting
# 13                           Beat-Reporting
# 14                           Beat-Reporting
# 15                           Beat-Reporting
# 16                           Beat-Reporting
# 20                Breaking-News-Photography
# 21                Breaking-News-Photography
# 22                Breaking-News-Photography
# 23                Breaking-News-Photography
# 24                Breaking-News-Photography
# 25                Breaking-News-Photography
# 26                Breaking-News-Photography
# 27                Breaking-News-Photography
# ...

# %% [markdown]
# ##  <font color = red > ['gender] wrong labeled

# %%
#wrong labeling as andy 
import numpy as np
# df.ix[(df['organizational'] == 'yes') & (df['gender'] == 'andy'),'gender'] = np.NaN
df.ix[(df['organizational'] == 'yes') & (df['gender'] == 'andy'),'gender']
# Out:
# 19      andy
# 34      andy
# 35      andy
# 39      andy
# 42      andy
# 43      andy
# 44      andy
# 45      andy
# 47      andy
# 48      andy
# 49      andy
# 50      andy
# 51      andy
# 52      andy
# 53      andy
# 54      andy
# 55      andy
# 56      andy
# 57      andy
# 58      andy
# 59      andy
# 370     andy
# 399     andy
# 403     andy
# 422     andy
# 423     andy
# 424     andy
# 441     andy
# 450     andy
# 452     andy
#         ...
# 997     andy
# 998     andy
# 999     andy
# 1000    andy
# 1001    andy
# 1002    andy
# 1003    andy
# 1004    andy
# 1005    andy
# 1006    andy
# 1007    andy
# 1008    andy
# 1009    andy
# 1011    andy
# 1012    andy
# 1013    andy
# 1014    andy
# 1016    andy
# 1017    andy
# 1018    andy
# 1019    andy
# 1021    andy
# 1022    andy
# 1080    andy
# 1108    andy
# 1110    andy
# 1111    andy
# 1112    andy
# 1113    andy
# 1114    andy
# Name: gender, dtype: object

# %% [markdown]
# ##Create a new copy of df

# %%
df2 = df.copy()
df2
# Out:
#                                    category  \
# 0                            Beat-Reporting
# 1                            Beat-Reporting
# 2                            Beat-Reporting
# 3                            Beat-Reporting
# 4                            Beat-Reporting
# 5                            Beat-Reporting
# 6                            Beat-Reporting
# 7                            Beat-Reporting
# 8                            Beat-Reporting
# 9                            Beat-Reporting
# 10                           Beat-Reporting
# 11                           Beat-Reporting
# 12                           Beat-Reporting
# 13                           Beat-Reporting
# 14                           Beat-Reporting
# 15                           Beat-Reporting
# 16                           Beat-Reporting
# 254               Editorial-Cartooning
# 261               Editorial-Cartooning
# 267                  Editorial-Writing
# 270                  Editorial-Writing
# 276                  Editorial-Writing
# 289                  Editorial-Writing
# 294                  Editorial-Writing
# 307                  Editorial-Writing
# 318                  Editorial-Writing
# ...

# %%
df2.to_csv('categorization_inprocess2.csv', sep=',', encoding='utf-8')

# %% [markdown]
# #========================ignore below===========================

# %%
# No award wrong labeling as andy #['organizational'] == none  # 23 rows 
df[(df['gender'] == 'andy') & (df['name'] == 'No Award')]

# %%
# No award wrong labeled as 'andy' #['organizational'] == no #5 rows
temp_df = df[(df['gender'] == 'andy') & (df['organizational'] == 'no')]
temp_df[temp_df['name'] == 'No award']
# Out:
#                     category publication      name  year organizational  \
# 46   Breaking-News-Reporting    No Award  No award  2011             no
# 270        Editorial-Writing    No Award  No award  2012             no
# 276        Editorial-Writing    No Award  No award  2008             no
# 480          Feature-Writing    No Award  No award  2014             no
# 490          Feature-Writing    No Award  No award  2004             no
#
#     first_name gender
# 46          No   andy
# 270         No   andy
# 276         No   andy
# 480         No   andy
# 490         No   andy

# %%
# indie
df['gender'] == 'female'|df['gender'] == 'mostly_female' & .value_counts()

# %% [markdown]
# #Dealing with missing data

# %%
import numpy as np
df['first_name'][38] = np.nan  #assign missing data
# Out:
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from IPython.kernel.zmq import kernelapp as app

# %%
#problem = [38,41, 267,289,446,467,678,778,1072,1082,1088]
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     688                 type_pprinters=self.type_printers,
#     689                 deferred_pprinters=self.deferred_printers)
# --> 690             printer.pretty(obj)
#     691             printer.flush()
#     692             return stream.getvalue()
#
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/lib/pretty.pyc in pretty(self, obj)
#     405                             if callable(meth):
#     406                                 return meth(obj, self, cycle)
# --> 407             return _default_pprint(obj, self, cycle)
#     408         finally:
#     409             self.end_group()
#
# /Users/Spepe/anaconda/lib/python2.7/site-packages/IPython/lib/pretty.pyc in _default_pprint(obj, p, cycle)
# ...

# %%
df['first_name'][1082]
# Out:
# 'No'

# %%
df[35:40]
# Out:
#                      category              publication               name  \
# 35  Breaking-News-Photography         Associated Press              Staff
# 36  Breaking-News-Photography  The Dallas Morning News  Cheryl Diaz Meyer
# 37  Breaking-News-Photography  The Dallas Morning News       David Leeson
# 38  Breaking-News-Photography      Rocky Mountain News  Photography Staff
# 39  Breaking-News-Photography       The New York Times              Staff
#
#     year organizational first_name  gender
# 35  2005            yes        NaN     NaN
# 36  2004             no     Cheryl  female
# 37  2004             no      David    male
# 38  2003            yes        NaN    andy
# 39  2002            yes        NaN     NaN

# %%
df[(df['first_name'].isnull()) & (df['organizational'] == 'yes')]
# Out:
#                        category                           publication  \
# 19    Breaking-News-Photography               St. Louis Post-Dispatch
# 34    Breaking-News-Photography               The Dallas Morning News
# 35    Breaking-News-Photography                      Associated Press
# 39    Breaking-News-Photography                    The New York Times
# 42      Breaking-News-Reporting                    The Seattle Times
# 43      Breaking-News-Reporting                      The Boston Globe
# 44      Breaking-News-Reporting                       The Denver Post
# 45      Breaking-News-Reporting            The Tuscaloosa (Ala.) News
# 47      Breaking-News-Reporting                     The Seattle Times
# 48      Breaking-News-Reporting                    The New York Times
# 49      Breaking-News-Reporting                   The Washington Post
# 50      Breaking-News-Reporting                         The Oregonian
# ...
